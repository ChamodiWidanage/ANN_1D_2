# %% [markdown]
# ### Importing the libraries

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Importing the dataset

# %%
# Importing the dataset
dataset_tnt = pd.read_excel('Peak_Pressure/PDataset_adj_TNT.xlsx')
dataset_compb = pd.read_excel('Peak_Pressure/PDataset_adj_CompB.xlsx')
dataset_all_p = pd.read_excel('Peak_Pressure/PDataset_adj.xlsx')
dataset_all_i = pd.read_excel('Peak_Impulse/IDataset_adj.xlsx')
dataset_all_a = pd.read_excel('Arrival_time/ADataset_adj.xlsx')

# %%
fig1, ax1 = plt.subplots(figsize = (7, 6))

ax1.set_facecolor('white')
n5, bins5, patches5 = plt.hist(x= [dataset_tnt['Explosive mass'],dataset_compb['Explosive mass']], bins= np.arange(dataset_tnt['Explosive mass'].min(), dataset_compb['Explosive mass'].max()+1),
                               color=['Red', 'Blue'],alpha=1, rwidth=0.85, label = ['TNT', 'Composition B'], stacked= 'True', align= 'mid')
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
plt.rcParams['font.size'] = 25
#plt.grid(visible= 'yes',axis='both', color = 'lightgrey')
plt.xlabel('Explosive Mass (kg)', fontsize = 23)
plt.ylabel('Frequency', fontsize = 23)
plt.xticks(ticks = [0, 5, 10, 15, 20, 25],fontsize = 23)
plt.yticks(fontsize = 23)
#plt.title('My Very Own Histogram')
#plt.text(23, 45, r'$\mu=15, b=3$')

plt.legend(loc=[0.25,1.03])
# Set a clean upper y-axis limit.
plt.ylim(0, 50)
plt.xlim(0, 26)

ax1.spines['left'].set_color('black')        
ax1.spines['bottom'].set_color('black')
ax1.spines['top'].set_color('black')        
ax1.spines['right'].set_color('black')


plt.savefig("Plot_mass.png", dpi = 600, bbox_inches = 'tight')
plt.show()

# %%
fig2, ax2 = plt.subplots(figsize = (7,6))

ax2.set_facecolor('white')
#bins = [0.5,1.4,3.4,5.4,7.4,9.4,11.4,13.4,15.4,17.4,19.4,19.9,21.4]
bins2 = np.arange(1,21,0.5)
plt.hist(x= [dataset_tnt['Standoff distance'],dataset_compb['Standoff distance']], bins =bins2,
                               color=['Red', 'Blue'],alpha=1, rwidth=0.6, label = ['TNT', 'Composition B'], stacked= 'True', align= 'left')
#np.arange(dataset_tnt['Standoff distance'].min(), dataset_compb['Standoff distance'].max()+1, 0.5)
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
plt.rcParams['font.size'] = 18
#plt.grid(visible= 'yes',axis='both', color = 'lightgrey')
plt.xlabel('Standoff Distance (m)', fontsize = 23)
plt.ylabel('Frequency', fontsize = 23)

# Set a clean upper y-axis limit.
plt.ylim(0, 30)
plt.xlim(0.5, 20.5)
plt.xticks(ticks = np.arange(0,21,2), rotation='vertical', fontsize = 23)
plt.yticks(fontsize = 23)
#plt.legend(loc=[0.4,1.03])

ax2.spines['left'].set_color('black')        
ax2.spines['bottom'].set_color('black')
ax2.spines['top'].set_color('black')        
ax2.spines['right'].set_color('black')
plt.savefig("Plot_sd.png", dpi = 600, bbox_inches = 'tight')
plt.show()

# %%
data = {'TNT': 294, 'Composition B': 294}
names = list(data.keys())
values = list(data.values())
fig3, ax3 = plt.subplots(figsize = (9, 6))
ax3.set_facecolor('white')
ax3.bar(names, values, color = ['red', 'blue'], width = 0.2, alpha=1)
plt.xlabel('Explosive Type')
plt.ylabel('Frequency')
#plt.grid(visible= 'yes',axis='y', color = 'lightgrey')
ax3.spines['left'].set_color('black')        
ax3.spines['bottom'].set_color('black')
ax3.spines['top'].set_color('black')        
ax3.spines['right'].set_color('black')

# %%
fig4, ax4 = plt.subplots(figsize = (4, 6))
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
ax4.set_facecolor('white')
plt.hist(x= dataset_all_p['Peak incident pressure (kPa)'], bins= 30, range = (100, 300), color='green',alpha=1, rwidth=0.85)

plt.rcParams['font.size'] = 18
#plt.grid(visible= 'yes',axis='both', color = 'lightgrey')
plt.xlabel('Peak Incident Pressure (kPa)', fontsize = 23)
plt.ylabel('Frequency', fontsize = 23)
print (dataset_all_p['Peak incident pressure (kPa)'].min())
plt.xlim(100, 300)
plt.yticks(fontsize = 23)
plt.xticks(fontsize = 23)

ax4.spines['left'].set_color('black')        
ax4.spines['bottom'].set_color('black')
ax4.spines['top'].set_color('black')        
ax4.spines['right'].set_color('black')
plt.savefig("Plot_pip.png", dpi = 600, bbox_inches = 'tight')
# Out:
# 103.07

# %%
fig4, ax4 = plt.subplots(figsize = (4, 6))
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
ax4.set_facecolor('white')
plt.hist(x= dataset_all_p['Peak incident pressure (kPa)'], bins= 30, range = (300, 8000), color='green',alpha=1, rwidth=0.85)

plt.rcParams['font.size'] = 18
#plt.grid(visible= 'yes',axis='both', color = 'lightgrey')
plt.xlabel('Peak Incident Pressure (kPa)', fontsize = 23)
plt.ylabel('Frequency', fontsize = 23)
print (dataset_all_p['Peak incident pressure (kPa)'].min())
plt.xlim(300, 8000)
plt.yticks(fontsize = 23)
plt.xticks(fontsize = 23)

ax4.spines['left'].set_color('black')        
ax4.spines['bottom'].set_color('black')
ax4.spines['top'].set_color('black')        
ax4.spines['right'].set_color('black')
plt.savefig("Plot_pip2.png", dpi = 600, bbox_inches = 'tight')
# Out:
# 103.07

# %%
fig7, ax7 = plt.subplots(figsize = (9, 6))
ax7.set_facecolor('white')
plt.hist(x= dataset_all_p['Peak incident pressure'], bins= 30, range = (100, 300), color='green',alpha=1, rwidth=0.85)

plt.rcParams['font.size'] = 18
#plt.grid(visible= 'yes',axis='both', color = 'lightgrey')
plt.xlabel('Peak Incident Pressure (kPa)')
plt.ylabel('Frequency')
print (dataset_all_p['Peak incident pressure'].min())
plt.xlim(100, 300)

ax7.spines['left'].set_color('black')        
ax7.spines['bottom'].set_color('black')
ax7.spines['top'].set_color('black')        
ax7.spines['right'].set_color('black')

# %%
fig5, ax5 = plt.subplots(figsize = (4, 6))
ax5.set_facecolor('white')
plt.hist(x= dataset_all_i['Peak impulse (kPa.ms)'], bins= 30, range = (dataset_all_i['Peak impulse (kPa.ms)'].min(), dataset_all_i['Peak impulse (kPa.ms)'].max()),color='green',alpha=1, rwidth=0.85)

plt.rcParams['font.size'] = 18
#plt.grid(visible= 'yes',axis='both', color = 'lightgrey')
plt.xlabel('Peak Impulse (kPa.ms)', fontsize = 23)
plt.ylabel('Frequency', fontsize = 23)
print (dataset_all_i['Peak impulse (kPa.ms)'].min(), dataset_all_i['Peak impulse (kPa.ms)'].max())
plt.xlim(0, )
plt.yticks(fontsize = 23)
plt.xticks(fontsize = 23)

ax5.spines['left'].set_color('black')        
ax5.spines['bottom'].set_color('black')
ax5.spines['top'].set_color('black')        
ax5.spines['right'].set_color('black')
plt.savefig("Plot_pi.png", dpi = 600, bbox_inches = 'tight')
# Out:
# 4.66652 435.32940674

# %%
fig6, ax6 = plt.subplots(figsize = (9, 6))
ax6.set_facecolor('white')
plt.hist(x= dataset_all_a['Time of arrival'], bins= 30, range = (dataset_all_a['Time of arrival'].min(), dataset_all_a['Time of arrival'].max()),color='#0504aa',alpha=1, rwidth=0.85)

plt.rcParams['font.size'] = 18
#plt.grid(visible= 'yes',axis='both', color = 'lightgrey')
plt.xlabel('Time of Arrival (ms)')
plt.ylabel('Frequency')
#plt.ylim(0, 200)
plt.xlim(0, 55)
print (dataset_all_a['Time of arrival'].max())

ax6.spines['left'].set_color('black')        
ax6.spines['bottom'].set_color('black')
ax6.spines['top'].set_color('black')        
ax6.spines['right'].set_color('black')

# %%
dataset_all_rp = pd.read_excel('Peak_Reflected_Pressure/RPDataset1.xlsx')

# %%
fig7, ax7 = plt.subplots(figsize = (5, 6))
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
ax7.set_facecolor('white')
plt.hist(x= dataset_all_rp['Peak reflected pressure(kPa)'], bins= 20, range = (dataset_all_rp['Peak reflected pressure(kPa)'].min(), 1000),color='green',alpha=1, rwidth=0.85)

plt.rcParams['font.size'] = 18
#plt.grid(visible= 'yes',axis='both', color = 'lightgrey')
plt.xlabel('Peak reflected pressure(kPa)', fontsize = 23)
plt.ylabel('Frequency', fontsize = 23)
print (dataset_all_rp['Peak reflected pressure(kPa)'].min(), dataset_all_rp['Peak reflected pressure(kPa)'].max())
plt.xlim(107,)
plt.yticks(fontsize = 23)
plt.xticks(fontsize = 23)

ax7.spines['left'].set_color('black')        
ax7.spines['bottom'].set_color('black')
ax7.spines['top'].set_color('black')        
ax7.spines['right'].set_color('black')
plt.savefig("Images/Plot_prp1.png", dpi = 600, bbox_inches = 'tight')
# Out:
# 107.516609 62403.475

# %%
fig8, ax8 = plt.subplots(figsize = (5, 6))
ax8.set_facecolor('white')
plt.hist(x= dataset_all_rp['Peak reflected pressure(kPa)'], bins= 30, range = (1000, dataset_all_rp['Peak reflected pressure(kPa)'].max()),color='green',alpha=1, rwidth=0.85)

plt.rcParams['font.size'] = 18
#plt.grid(visible= 'yes',axis='both', color = 'lightgrey')
plt.xlabel('Peak reflected pressure(kPa)', fontsize = 23)
plt.ylabel('Frequency', fontsize = 23)
print (dataset_all_rp['Peak reflected pressure(kPa)'].min(), dataset_all_rp['Peak reflected pressure(kPa)'].max())
plt.xlim(1000, )
plt.yticks(fontsize = 23)
plt.xticks(fontsize = 23)

ax8.spines['left'].set_color('black')        
ax8.spines['bottom'].set_color('black')
ax8.spines['top'].set_color('black')        
ax8.spines['right'].set_color('black')
plt.savefig("Images/Plot_prp2.png", dpi = 600, bbox_inches = 'tight')
# Out:
# 107.516609 62403.475

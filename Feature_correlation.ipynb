# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Set the font to New Times Roman for Seaborn
sns.set(font='serif', style='whitegrid')
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

# %% [markdown]
# ### Peak pressure

# %%
# Importing the dataset
dataset_1 = pd.read_excel('Peak_Pressure/PDataset_adj.xlsx')
dataset_1['Explosive type'] = dataset_1['Explosive type'].astype('category')
dataset_1.describe(include='category')
# Out:
#        Explosive type
# count             588
# unique              2
# top     Composition B
# freq              294

# %%
dataset_1.corr()
# Out:
# C:\Users\z5379606\AppData\Local\Temp\ipykernel_28396\3325122408.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset_1.corr()
#                               Explosive mass (kg)  Standoff distance (m)  \
# Explosive mass (kg)                  1.000000e+00          -1.418747e-16
# Standoff distance (m)               -1.418747e-16           1.000000e+00
# Peak incident pressure (kPa)         1.634606e-01          -4.920233e-01
#
#                               Peak incident pressure (kPa)
# Explosive mass (kg)                               0.163461
# Standoff distance (m)                            -0.492023
# Peak incident pressure (kPa)                      1.000000

# %%
# Calculate the value
#corrMatrix1 = dataset_1.corr(method = 'kendall')
corrMatrix1 = dataset_1.corr(method = 'spearman')


# Set the font to New Times Roman for Seaborn
sns.set(font='serif', font_scale=2)
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

# Create an instance of the PairGrid class.
grid = sns.PairGrid(data= dataset_1,
                    hue = "Explosive type",
                    vars = ["Explosive mass (kg)", "Standoff distance (m)", "Peak incident pressure (kPa)"],
                    palette=[ "red", "blue"],
                    diag_sharey=False,
                    corner=True,
                    height = 4)

#hue_marker={'Composition B':'o','TNT' :'^'}

# Map a scatter plot to the upper triangle
grid.map_offdiag(sns.scatterplot, alpha = 0.7,  style = dataset_1["Explosive type"], style_order = ["TNT", "Composition B"])

# Map a histogram to the diagonal
#grid.map_diag(sns.kdeplot)


# Map a density plot to the lower triangle
#grid = grid.map_lower(sns.kdeplot, cmap = 'Reds')
grid.add_legend(loc = (0.65,0.75))

# Add correlation coefficients to the plot
#for i, j in zip(*plt.np.tril_indices_from(grid.axes, k=-1)):
 #   r1 = corrMatrix1.iloc[i, j]
  #  grid.axes[i, j].annotate(f"K = {r1:.2f}", xy=(0.1, 1.02), xycoords='axes fraction', size = 18, color = 'Green')

# Add correlation coefficients to the plot
for l, m in zip(*plt.np.tril_indices_from(grid.axes, k=-1)):
    r2 = corrMatrix1.iloc[l, m]
    grid.axes[l, m].annotate(f"Spearman = {r2:.2f}", xy=(.2, 1.02), xycoords='axes fraction', size = 23, color = 'Green')


sns.despine()

plt.savefig('Peak_Pressure/corr.png', dpi = 600, bbox_inches = 'tight')
# Out:
# C:\Users\z5379606\AppData\Local\Temp\ipykernel_61132\2806006740.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrMatrix1 = dataset_1.corr(method = 'spearman')

# %% [markdown]
# ### Peak impulse

# %%
# Importing the dataset
dataset_2 = pd.read_excel('Peak_Impulse/IDataset_adj.xlsx')
dataset_2['Explosive type'] = dataset_2['Explosive type'].astype('category')
dataset_2.describe(include='category')
# Out:
#        Explosive type
# count             588
# unique              2
# top     Composition B
# freq              294

# %%
dataset_2.corr()
# Out:
# C:\Users\z5379606\AppData\Local\Temp\ipykernel_28396\4097578792.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset_2.corr()
#                        Explosive mass (kg)  Standoff distance (m)  \
# Explosive mass (kg)           1.000000e+00          -1.490452e-16
# Standoff distance (m)        -1.490452e-16           1.000000e+00
# Peak impulse (kPa.ms)         4.796250e-01          -7.258849e-01
#
#                        Peak impulse (kPa.ms)
# Explosive mass (kg)                 0.479625
# Standoff distance (m)              -0.725885
# Peak impulse (kPa.ms)               1.000000

# %%
# Calculate the value
#corrMatrix1 = dataset_1.corr(method = 'kendall')
corrMatrix2 = dataset_2.corr(method = 'spearman')

# Set the font to New Times Roman for Seaborn
sns.set(font='serif', font_scale=2)
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

# Create an instance of the PairGrid class.
grid = sns.PairGrid(data= dataset_2,
                    hue = "Explosive type",
                    vars = ["Explosive mass (kg)", "Standoff distance (m)", "Peak impulse (kPa.ms)"],
                    palette=[ "red", "blue"],
                    diag_sharey=False,
                    corner=True,
                    height = 4)

#hue_marker={'Composition B':'o','TNT' :'^'}

# Map a scatter plot to the upper triangle
grid.map_offdiag(sns.scatterplot, alpha = 0.7,  style = dataset_1["Explosive type"], style_order = ["TNT", "Composition B"])

# Map a histogram to the diagonal
#grid.map_diag(sns.kdeplot)


# Map a density plot to the lower triangle
#grid = grid.map_lower(sns.kdeplot, cmap = 'Reds')
grid.add_legend(loc = (0.65,0.75))

# Add correlation coefficients to the plot
#for i, j in zip(*plt.np.tril_indices_from(grid.axes, k=-1)):
 #   r1 = corrMatrix1.iloc[i, j]
  #  grid.axes[i, j].annotate(f"K = {r1:.2f}", xy=(0.1, 1.02), xycoords='axes fraction', size = 18, color = 'Green')

# Add correlation coefficients to the plot
for l, m in zip(*plt.np.tril_indices_from(grid.axes, k=-1)):
    r2 = corrMatrix2.iloc[l, m]
    grid.axes[l, m].annotate(f"Spearman = {r2:.2f}", xy=(.2, 1.02), xycoords='axes fraction', size = 23, color = 'Green')


sns.despine()

plt.savefig('Peak_Impulse/corr.png', dpi = 600, bbox_inches = 'tight')
# Out:
# C:\Users\z5379606\AppData\Local\Temp\ipykernel_61132\3384633785.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrMatrix2 = dataset_2.corr(method = 'spearman')

# %% [markdown]
# ### Arrival time

# %%
# Importing the dataset
dataset_3 = pd.read_excel('Arrival_Time/ADataset_adj.xlsx')
dataset_3['Explosive type'] = dataset_3['Explosive type'].astype('category')
dataset_3.describe(include='category')
# Out:
#        Explosive type
# count             588
# unique              2
# top     Composition B
# freq              294

# %%
dataset_3.corr()
# Out:
# C:\Users\z5379606\AppData\Local\Temp\ipykernel_28396\1374289740.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset_3.corr()
#                    Explosive mass  Standoff distance  Time of arrival
# Explosive mass       1.000000e+00       1.326554e-16        -0.145384
# Standoff distance    1.326554e-16       1.000000e+00         0.981452
# Time of arrival     -1.453837e-01       9.814524e-01         1.000000

# %%
# Calculate the value
#corrMatrix1 = dataset_1.corr(method = 'kendall')
corrMatrix3 = dataset_3.corr(method = 'spearman')

# Set the font to New Times Roman for Seaborn
sns.set(font='serif', font_scale=2)
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

# Create an instance of the PairGrid class.
grid = sns.PairGrid(data= dataset_3,
                    hue = "Explosive type",
                    vars = ["Explosive mass", "Standoff distance", "Time of arrival"],
                    palette=[ "red", "blue"],
                    diag_sharey=False,
                    corner=True,
                    height = 4)

#hue_marker={'Composition B':'o','TNT' :'^'}

# Map a scatter plot to the upper triangle
grid.map_offdiag(sns.scatterplot, alpha = 0.7,  style = dataset_1["Explosive type"], style_order = ["TNT", "Composition B"])

# Map a histogram to the diagonal
#grid.map_diag(sns.kdeplot)


# Map a density plot to the lower triangle
#grid = grid.map_lower(sns.kdeplot, cmap = 'Reds')
grid.add_legend(loc = (0.65,0.75))

# Add correlation coefficients to the plot
#for i, j in zip(*plt.np.tril_indices_from(grid.axes, k=-1)):
 #   r1 = corrMatrix1.iloc[i, j]
  #  grid.axes[i, j].annotate(f"K = {r1:.2f}", xy=(0.1, 1.02), xycoords='axes fraction', size = 18, color = 'Green')

# Add correlation coefficients to the plot
for l, m in zip(*plt.np.tril_indices_from(grid.axes, k=-1)):
    r2 = corrMatrix3.iloc[l, m]
    grid.axes[l, m].annotate(f"Spearman = {r2:.2f}", xy=(.2, 1.02), xycoords='axes fraction', size = 18, color = 'Green')


sns.despine()
plt.show()
# Out:
# C:\Users\z5379606\AppData\Local\Temp\ipykernel_28396\884663823.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrMatrix3 = dataset_3.corr(method = 'spearman')

# %%
import seaborn as sn
from pandas import DataFrame

t=['Charge_type', 'Charge_size', 'Standoff_distance','Incident_pressure']

s=abs(dataset[t].corr()['Incident_pressure'])
p=s.sort_values(ascending=True)
p.index

t=p.index[::-1]
df = pd.DataFrame(dataset[t],columns=t)
fig, ax = plt.subplots(figsize=(15,12),sharex=True, sharey=True) 
corrMatrix = dataset.corr()
sn.heatmap(corrMatrix, cmap="hot", annot=True,annot_kws={"size": 18},ax=ax)

# %%
plt.figure(figsize=(10,6))
n, bins, patches = plt.hist(x= dataset_1['Explosive mass'], bins= np.arange(dataset_1['Explosive mass'].min(), dataset_1['Explosive mass'].max()+1, 0.5), color='#0504aa',
                            alpha=0.65, rwidth=0.85)
plt.rcParams['font.size'] = 18
plt.grid(axis='both', alpha=0.75)
plt.xlabel('Explosive Mass (kg)')
plt.ylabel('Frequency')
#plt.title('My Very Own Histogram')
#plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 == 0 else maxfreq + 10)
# Out:
# (0.0, 52.0)

# %%
plt.figure(figsize=(10,6))
n, bins, patches = plt.hist(x= dataset['Standoff distance'], bins= np.arange(dataset['Standoff distance'].min(), dataset['Standoff distance'].max()+1, 0.5), color='#0504aa',alpha=0.65, rwidth=0.85)
plt.rcParams['font.size'] = 18
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Standoff Distance (m)')
plt.ylabel('Frequency')
#plt.title('My Very Own Histogram')
#plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 ==0 else maxfreq + 2)
# Out:
# (0.0, 16.0)

# %%
plt.figure(figsize=(10,6))
n, bins, patches = plt.hist(x= dataset['Peak incident pressure'], bins= 30, range = (dataset['Peak incident pressure'].min(), 300), color='#0504aa',
                            alpha=0.65, rwidth=0.85)
plt.rcParams['font.size'] = 18
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Peak Incident Pressure (kPa)')
plt.ylabel('Frequency')
#plt.title('My Very Own Histogram')
#plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq = n.max()
print ('maxfreq',maxfreq, maxfreq % 10)
print (dataset['Peak incident pressure'].min())
# Set a clean upper y-axis limit.
plt.ylim(ymax=(np.ceil(maxfreq / 10)+1) * 10 if maxfreq % 10 == 0 else maxfreq + 10)
#plt.xlim(0, 500)
# Out:
# maxfreq 89.0 9.0
# 103.175
# (0.0, 99.0)

# %%
plt.figure(figsize=(10,6))
n, bins, patches = plt.hist(x= dataset['Peak incident pressure'], bins= 100, range = (dataset['Peak incident pressure'].min(), dataset['Peak incident pressure'].max()), color='#0504aa',
                            alpha=0.65, rwidth=0.85)
plt.rcParams['font.size'] = 18
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Peak Incident Pressure (kPa)')
plt.ylabel('Frequency')
#plt.title('My Very Own Histogram')
#plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq = n.max()
print (maxfreq, maxfreq % 10)
# Set a clean upper y-axis limit.
#plt.ylim(ymax=(np.ceil(maxfreq / 10)+0.5) * 10 if maxfreq % 10 == 0 else maxfreq + 5)
#plt.xlim(250, 8500)
# Out:
# 397.0 7.0

# %%
plt.figure(figsize=(10,6))
n, bins, patches = plt.hist(x= dataset['Peak incident pressure'], bins = np.arange(dataset['Peak incident pressure'].min(), 300), color='#0504aa',
                            alpha=0.65, rwidth=0.85)
plt.rcParams['font.size'] = 18
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Peak Incident Pressure (kPa)')
plt.ylabel('Frequency')
#plt.title('My Very Own Histogram')
#plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq = n.max()
print ('maxfreq',maxfreq, maxfreq % 10)
print (dataset['Peak incident pressure'].min())
# Set a clean upper y-axis limit.
#plt.ylim(ymax=(np.ceil(maxfreq / 10)+1) * 10 if maxfreq % 10 == 0 else maxfreq + 10)
#plt.xlim(0, 500)
# Out:
# maxfreq 17.0 7.0
# 103.175

# %%
plt.figure(figsize=(10,6))
n, bins, patches = plt.hist(x= dataset['Peak incident pressure'], bins = np.arange( 300,dataset['Peak incident pressure'].max(), 200), color='#0504aa',
                            alpha=0.65, rwidth=0.85)
plt.rcParams['font.size'] = 18
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Peak Incident Pressure (kPa)')
plt.ylabel('Frequency')
#plt.title('My Very Own Histogram')
#plt.text(23, 45, r'$\mu=15, b=3$')
max = bins.max()
print ('max',max)
#print (dataset['Peak incident pressure'].min())
# Set a clean upper y-axis limit.
#plt.ylim(ymax=(np.ceil(maxfreq / 10)+1) * 10 if maxfreq % 10 == 0 else maxfreq + 10)
#plt.xlim(0, 500)
# Out:
# max 8100.0

# %%
dataset_tnt = pd.read_excel('Dataset3_TNT.xlsx')
dataset_tnt = dataset_tnt.rename(columns={'Charge_type': 'Charge type',
                            'Charge_size' : 'Charge size',
                            'Standoff_distance' : 'Standoff distance',
                            'Incident_pressure' : 'Peak incident pressure'})

# %%
plt.figure(figsize=(10,6))
n1, bins1, patches1 = plt.hist(x= dataset_tnt['Charge size'], bins= np.arange(dataset_tnt['Charge size'].min(), dataset_tnt['Charge size'].max()+1, 0.5), color='#0504aa',
                            alpha=0.65, rwidth=0.85)
plt.rcParams['font.size'] = 18
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Charge Size (kg)')
plt.ylabel('Frequency')
#plt.title('My Very Own Histogram')
#plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq1 = n1.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq1 / 10) * 10 if maxfreq1 % 10 == 0 else maxfreq1 + 2)
# Out:
# (0.0, 21.0)

# %%
plt.figure(figsize=(10,6))
n2, bins2, patches2 = plt.hist(x= dataset_tnt['Standoff distance'], bins= np.arange(dataset_tnt['Standoff distance'].min(), dataset_tnt['Standoff distance'].max()+1, 0.5), color='#0504aa',alpha=0.65, rwidth=0.85)
plt.rcParams['font.size'] = 18
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Standoff Distance (m)')
plt.ylabel('Frequency')
#plt.title('My Very Own Histogram')
#plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq2 = n2.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq2 / 10) * 10 if maxfreq2 % 10 ==0 else maxfreq2 + 2)
# Out:
# (0.0, 16.0)

# %%
dataset_compb = pd.read_excel('Dataset3_CompB.xlsx')
dataset_compb = dataset_compb.rename(columns={'Charge_type': 'Charge type',
                            'Charge_size' : 'Charge size',
                            'Standoff_distance' : 'Standoff distance',
                            'Incident_pressure' : 'Peak incident pressure'})

# %%
plt.figure(figsize=(10,6))
n3, bins3, patches3 = plt.hist(x= dataset_compb['Charge size'], bins= np.arange(dataset_compb['Charge size'].min(), dataset_compb['Charge size'].max()+1, 0.5), color='#0504aa',
                            alpha=0.65, rwidth=0.85)
plt.rcParams['font.size'] = 18
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Charge Size (kg)')
plt.ylabel('Frequency')
#plt.title('My Very Own Histogram')
#plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq3 = n3.max()
print (maxfreq3)
# Set a clean upper y-axis limit.
plt.ylim(0, maxfreq3+2)
# Out:
# 20.0
# (0.0, 22.0)

# %%
plt.figure(figsize=(10,6))
n4, bins4, patches4 = plt.hist(x= dataset_compb['Standoff distance'], bins= np.arange(dataset_compb['Standoff distance'].min(), dataset_compb['Standoff distance'].max()+1, 0.5), color='#0504aa',alpha=0.65, rwidth=0.85)
plt.rcParams['font.size'] = 18
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Standoff Distance (m)')
plt.ylabel('Frequency')
#plt.title('My Very Own Histogram')
#plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq4 = n4.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq4 / 10) * 10 if maxfreq4 % 10 ==0 else maxfreq4 + 2)
# Out:
# (0.0, 16.0)

# %% [markdown]
# ## Both in one

# %%
plt.figure(figsize=(10,6))
n5, bins5, patches5 = plt.hist(x= [dataset_tnt['Charge size'],dataset_compb['Charge size']], bins= np.arange(dataset_tnt['Charge size'].min(), dataset_compb['Charge size'].max()+1, 0.5),
                               color=['Red', 'Blue'],alpha=0.65, rwidth=0.85, label = ['TNT', 'CompB'])
plt.rcParams['font.size'] = 18
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Charge Size (kg)')
plt.ylabel('Frequency')
#plt.title('My Very Own Histogram')
#plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq5 = n5.max()
plt.legend(loc=[0.4,1.03])
# Set a clean upper y-axis limit.
plt.ylim(0, maxfreq5 + 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 n5, bins5, patches5 = plt.hist(x= [dataset_tnt['Charge size'],dataset_compb['Charge size']], bins= np.arange(dataset_tnt['Charge size'].min(), dataset_compb['Charge size'].max()+1, 0.5),
#       3                                color=['Red', 'Blue'],alpha=0.65, rwidth=0.85, label = ['TNT', 'CompB'], stacked= 'True')
#       4 plt.rcParams['font.size'] = 18
#       5 plt.grid(axis='y', alpha=0.75)
#
# NameError: name 'dataset_tnt' is not defined

# %%
plt.figure(figsize=(10,6))
n6, bins6, patches6 = plt.hist(x= [dataset_tnt['Standoff distance'],dataset_compb['Standoff distance']], bins= np.arange(dataset_tnt['Standoff distance'].min(), dataset_compb['Standoff distance'].max()+1, 0.5),
                               color=['Red', 'Blue'],alpha=0.65, rwidth=0.85, label = ['TNT', 'CompB'])
plt.rcParams['font.size'] = 18
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Standoff Distance (m)')
plt.ylabel('Frequency')
#plt.title('My Very Own Histogram')
#plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq6 = n6.max()
plt.legend(loc=[0.4,1.03])
# Set a clean upper y-axis limit.
plt.ylim(0, maxfreq6 + 2)
# Out:
# (0.0, 16.0)

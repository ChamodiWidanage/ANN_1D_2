# %% [markdown]
# ## Import libraries

# %%
from pathlib import Path
import pandas as pd
import math
import openpyxl

# %% [markdown]
# # Create peak pressure file - Attempt 1 (without peak index)

# %% [markdown]
# ## Access input folders

# %%
#Access input folder
input_dir1 = Path ("8series_tracers_pressure")
print ("1",input_dir1)

#Access folders inside input folder
input_dir2 =  [folder for folder in input_dir1.iterdir() if folder.is_dir()]
print ("2",input_dir2)
# Out:
# 1 8series_tracers_pressure
# 2 [WindowsPath('8series_tracers_pressure/L801'), WindowsPath('8series_tracers_pressure/L803'), WindowsPath('8series_tracers_pressure/L805'), WindowsPath('8series_tracers_pressure/L807'), WindowsPath('8series_tracers_pressure/L811'), WindowsPath('8series_tracers_pressure/L815'), WindowsPath('8series_tracers_pressure/L819'), WindowsPath('8series_tracers_pressure/L823'), WindowsPath('8series_tracers_pressure/L826'), WindowsPath('8series_tracers_pressure/L831'), WindowsPath('8series_tracers_pressure/L834'), WindowsPath('8series_tracers_pressure/L838'), WindowsPath('8series_tracers_pressure/L842'), WindowsPath('8series_tracers_pressure/L846'), WindowsPath('8series_tracers_pressure/L850')]

# %% [markdown]
# ## Create output files 1

# %%
# %%timeit -r1 -n1
# define current work directory
current_dir = Path.cwd()

# access the template to be used to generate files
excel_template = current_dir/ "Template.xlsx"

# Access each folder inside input folder
for folder in input_dir2:
    print ("folder", folder)
    
    # Make a list of data file names
    files = list(folder.rglob("*"))
    
    # Make a set of file names
    keys = set (file.stem for file in files)
    
    # Use xlwings library to create excel files
    with xw.App (visible = False) as app:
        
        # for loop for keys
        for key in keys:
            
            # Open template excel file
            wb = app.books.open(excel_template)
            
            # for loop for files
            for file in files:
                if file.stem == key:
                    print ("file.stem = ", file.stem)
                    print ("key = ", key)
                    df = pd.read_csv(file, delimiter="\s+", skiprows = 8, skipfooter = 1, header = None, names = ["time", "pressure"])
                    wb.sheets[0].range("A1").options(index=False).value = df
            output_dir = current_dir/ "Pressure_curves_excel"
            output_dir.mkdir(exist_ok = True)
            output_dir1 = output_dir/ folder.stem
            output_dir1.mkdir(exist_ok = True)
            wb.save(output_dir1/f"{key}.xlsx")
        #print ("file",folder.stem, file.stem)
        #current_dir = Path.cwd()
        #excel_template = current_dir/ "Template.xlsx"

# %% [markdown]
# ## Create output files 2

# %%
df = pd.DataFrame(columns = ['Explosive type', 'Explosive mass', 'Standoff_distance', 'Peak_Pressure'])
print (df)

# Access each folder inside input folder
for folder in input_dir2:
    print ("folder", folder)
    charge_mass = int(folder.stem[2:])/2
    
    # Make a list of data file names
    files = list(folder.rglob("*"))
        
    # Access each file 
    for file in files:
        print ("file", file)
        stand_dis = int(file.stem[1:])/2
            
        # Create a dataframe out of data files and use delimiters
        df1 = pd.read_csv(file,
                          delimiter="\s+",
                          skiprows = 7,
                          nrows= 1,
                          engine = 'python',
                          header = None)
            
        # append rows to an empty DataFrame
        new_row = {'Explosive type': ['Composition B'], 'Explosive mass' : [charge_mass], 'Standoff_distance' : [stand_dis], 'Peak_Pressure' : [df1.iloc[0,2]/1000]}
        new_row_data = pd.DataFrame(new_row)
        df = pd.concat([df, new_row_data], ignore_index = True)
print (df)
# Out:
# Empty DataFrame
# Columns: [Explosive type, Explosive mass, Standoff_distance, Peak_Pressure]
# Index: []
# folder 8series_tracers_pressure\L801
# file 8series_tracers_pressure\L801\T11
# file 8series_tracers_pressure\L801\T13
# file 8series_tracers_pressure\L801\T15
# file 8series_tracers_pressure\L801\T17
# file 8series_tracers_pressure\L801\T19
# file 8series_tracers_pressure\L801\T2
# file 8series_tracers_pressure\L801\T21
# file 8series_tracers_pressure\L801\T23
# file 8series_tracers_pressure\L801\T25
# file 8series_tracers_pressure\L801\T27
# file 8series_tracers_pressure\L801\T29
# file 8series_tracers_pressure\L801\T3
# file 8series_tracers_pressure\L801\T31
# file 8series_tracers_pressure\L801\T33
# file 8series_tracers_pressure\L801\T35
# file 8series_tracers_pressure\L801\T37
# file 8series_tracers_pressure\L801\T39
# file 8series_tracers_pressure\L801\T40
# file 8series_tracers_pressure\L801\T5
# file 8series_tracers_pressure\L801\T7
# file 8series_tracers_pressure\L801\T9
# folder 8series_tracers_pressure\L803
# file 8series_tracers_pressure\L803\T11
# file 8series_tracers_pressure\L803\T13
# file 8series_tracers_pressure\L803\T15
# file 8series_tracers_pressure\L803\T17
# file 8series_tracers_pressure\L803\T19
# file 8series_tracers_pressure\L803\T2
# file 8series_tracers_pressure\L803\T21
# file 8series_tracers_pressure\L803\T23
# file 8series_tracers_pressure\L803\T25
# file 8series_tracers_pressure\L803\T27
# file 8series_tracers_pressure\L803\T29
# file 8series_tracers_pressure\L803\T3
# file 8series_tracers_pressure\L803\T31
# file 8series_tracers_pressure\L803\T33
# file 8series_tracers_pressure\L803\T35
# file 8series_tracers_pressure\L803\T37
# file 8series_tracers_pressure\L803\T39
# file 8series_tracers_pressure\L803\T40
# file 8series_tracers_pressure\L803\T5
# file 8series_tracers_pressure\L803\T7
# file 8series_tracers_pressure\L803\T9
# folder 8series_tracers_pressure\L805
# file 8series_tracers_pressure\L805\T11
# file 8series_tracers_pressure\L805\T13
# file 8series_tracers_pressure\L805\T15
# file 8series_tracers_pressure\L805\T17
# file 8series_tracers_pressure\L805\T19
# file 8series_tracers_pressure\L805\T2
# file 8series_tracers_pressure\L805\T21
# file 8series_tracers_pressure\L805\T23
# file 8series_tracers_pressure\L805\T25
# file 8series_tracers_pressure\L805\T27
# file 8series_tracers_pressure\L805\T29
# file 8series_tracers_pressure\L805\T3
# file 8series_tracers_pressure\L805\T31
# file 8series_tracers_pressure\L805\T33
# file 8series_tracers_pressure\L805\T35
# file 8series_tracers_pressure\L805\T37
# file 8series_tracers_pressure\L805\T39
# file 8series_tracers_pressure\L805\T40
# file 8series_tracers_pressure\L805\T5
# file 8series_tracers_pressure\L805\T7
# file 8series_tracers_pressure\L805\T9
# folder 8series_tracers_pressure\L807
# file 8series_tracers_pressure\L807\T11
# file 8series_tracers_pressure\L807\T13
# file 8series_tracers_pressure\L807\T15
# file 8series_tracers_pressure\L807\T17
# file 8series_tracers_pressure\L807\T19
# file 8series_tracers_pressure\L807\T2
# file 8series_tracers_pressure\L807\T21
# file 8series_tracers_pressure\L807\T23
# file 8series_tracers_pressure\L807\T25
# file 8series_tracers_pressure\L807\T27
# file 8series_tracers_pressure\L807\T29
# file 8series_tracers_pressure\L807\T3
# file 8series_tracers_pressure\L807\T31
# file 8series_tracers_pressure\L807\T33
# file 8series_tracers_pressure\L807\T35
# file 8series_tracers_pressure\L807\T37
# file 8series_tracers_pressure\L807\T39
# file 8series_tracers_pressure\L807\T40
# file 8series_tracers_pressure\L807\T5
# file 8series_tracers_pressure\L807\T7
# file 8series_tracers_pressure\L807\T9
# folder 8series_tracers_pressure\L811
# file 8series_tracers_pressure\L811\T11
# file 8series_tracers_pressure\L811\T13
# file 8series_tracers_pressure\L811\T15
# file 8series_tracers_pressure\L811\T17
# file 8series_tracers_pressure\L811\T19
# file 8series_tracers_pressure\L811\T2
# file 8series_tracers_pressure\L811\T21
# file 8series_tracers_pressure\L811\T23
# file 8series_tracers_pressure\L811\T25
# file 8series_tracers_pressure\L811\T27
# file 8series_tracers_pressure\L811\T29
# file 8series_tracers_pressure\L811\T3
# file 8series_tracers_pressure\L811\T31
# file 8series_tracers_pressure\L811\T33
# file 8series_tracers_pressure\L811\T35
# file 8series_tracers_pressure\L811\T37
# file 8series_tracers_pressure\L811\T39
# file 8series_tracers_pressure\L811\T40
# file 8series_tracers_pressure\L811\T5
# file 8series_tracers_pressure\L811\T7
# file 8series_tracers_pressure\L811\T9
# folder 8series_tracers_pressure\L815
# file 8series_tracers_pressure\L815\T11
# file 8series_tracers_pressure\L815\T13
# file 8series_tracers_pressure\L815\T15
# file 8series_tracers_pressure\L815\T17
# file 8series_tracers_pressure\L815\T19
# file 8series_tracers_pressure\L815\T2
# file 8series_tracers_pressure\L815\T21
# file 8series_tracers_pressure\L815\T23
# file 8series_tracers_pressure\L815\T25
# file 8series_tracers_pressure\L815\T27
# file 8series_tracers_pressure\L815\T29
# file 8series_tracers_pressure\L815\T3
# file 8series_tracers_pressure\L815\T31
# file 8series_tracers_pressure\L815\T33
# file 8series_tracers_pressure\L815\T35
# file 8series_tracers_pressure\L815\T37
# file 8series_tracers_pressure\L815\T39
# file 8series_tracers_pressure\L815\T40
# file 8series_tracers_pressure\L815\T5
# file 8series_tracers_pressure\L815\T7
# file 8series_tracers_pressure\L815\T9
# folder 8series_tracers_pressure\L819
# file 8series_tracers_pressure\L819\T11
# file 8series_tracers_pressure\L819\T13
# file 8series_tracers_pressure\L819\T15
# file 8series_tracers_pressure\L819\T17
# file 8series_tracers_pressure\L819\T19
# file 8series_tracers_pressure\L819\T2
# file 8series_tracers_pressure\L819\T21
# file 8series_tracers_pressure\L819\T23
# file 8series_tracers_pressure\L819\T25
# file 8series_tracers_pressure\L819\T27
# file 8series_tracers_pressure\L819\T29
# file 8series_tracers_pressure\L819\T3
# file 8series_tracers_pressure\L819\T31
# file 8series_tracers_pressure\L819\T33
# file 8series_tracers_pressure\L819\T35
# file 8series_tracers_pressure\L819\T37
# file 8series_tracers_pressure\L819\T39
# file 8series_tracers_pressure\L819\T40
# file 8series_tracers_pressure\L819\T5
# file 8series_tracers_pressure\L819\T7
# file 8series_tracers_pressure\L819\T9
# folder 8series_tracers_pressure\L823
# file 8series_tracers_pressure\L823\T11
# file 8series_tracers_pressure\L823\T13
# file 8series_tracers_pressure\L823\T15
# file 8series_tracers_pressure\L823\T17
# file 8series_tracers_pressure\L823\T19
# file 8series_tracers_pressure\L823\T2
# file 8series_tracers_pressure\L823\T21
# file 8series_tracers_pressure\L823\T23
# file 8series_tracers_pressure\L823\T25
# file 8series_tracers_pressure\L823\T27
# file 8series_tracers_pressure\L823\T29
# file 8series_tracers_pressure\L823\T3
# file 8series_tracers_pressure\L823\T31
# file 8series_tracers_pressure\L823\T33
# file 8series_tracers_pressure\L823\T35
# file 8series_tracers_pressure\L823\T37
# file 8series_tracers_pressure\L823\T39
# file 8series_tracers_pressure\L823\T40
# file 8series_tracers_pressure\L823\T5
# file 8series_tracers_pressure\L823\T7
# file 8series_tracers_pressure\L823\T9
# folder 8series_tracers_pressure\L826
# file 8series_tracers_pressure\L826\T11
# file 8series_tracers_pressure\L826\T13
# file 8series_tracers_pressure\L826\T15
# file 8series_tracers_pressure\L826\T17
# file 8series_tracers_pressure\L826\T19
# file 8series_tracers_pressure\L826\T2
# file 8series_tracers_pressure\L826\T21
# file 8series_tracers_pressure\L826\T23
# file 8series_tracers_pressure\L826\T25
# file 8series_tracers_pressure\L826\T27
# file 8series_tracers_pressure\L826\T29
# file 8series_tracers_pressure\L826\T3
# file 8series_tracers_pressure\L826\T31
# file 8series_tracers_pressure\L826\T33
# file 8series_tracers_pressure\L826\T35
# file 8series_tracers_pressure\L826\T37
# file 8series_tracers_pressure\L826\T39
# file 8series_tracers_pressure\L826\T40
# file 8series_tracers_pressure\L826\T5
# file 8series_tracers_pressure\L826\T7
# file 8series_tracers_pressure\L826\T9
# folder 8series_tracers_pressure\L831
# file 8series_tracers_pressure\L831\T11
# file 8series_tracers_pressure\L831\T13
# file 8series_tracers_pressure\L831\T15
# file 8series_tracers_pressure\L831\T17
# file 8series_tracers_pressure\L831\T19
# file 8series_tracers_pressure\L831\T2
# file 8series_tracers_pressure\L831\T21
# file 8series_tracers_pressure\L831\T23
# file 8series_tracers_pressure\L831\T25
# file 8series_tracers_pressure\L831\T27
# file 8series_tracers_pressure\L831\T29
# file 8series_tracers_pressure\L831\T3
# file 8series_tracers_pressure\L831\T31
# file 8series_tracers_pressure\L831\T33
# file 8series_tracers_pressure\L831\T35
# file 8series_tracers_pressure\L831\T37
# file 8series_tracers_pressure\L831\T39
# file 8series_tracers_pressure\L831\T40
# file 8series_tracers_pressure\L831\T5
# file 8series_tracers_pressure\L831\T7
# file 8series_tracers_pressure\L831\T9
# folder 8series_tracers_pressure\L834
# file 8series_tracers_pressure\L834\T11
# file 8series_tracers_pressure\L834\T13
# file 8series_tracers_pressure\L834\T15
# file 8series_tracers_pressure\L834\T17
# file 8series_tracers_pressure\L834\T19
# file 8series_tracers_pressure\L834\T2
# file 8series_tracers_pressure\L834\T21
# file 8series_tracers_pressure\L834\T23
# file 8series_tracers_pressure\L834\T25
# file 8series_tracers_pressure\L834\T27
# file 8series_tracers_pressure\L834\T29
# file 8series_tracers_pressure\L834\T3
# file 8series_tracers_pressure\L834\T31
# file 8series_tracers_pressure\L834\T33
# file 8series_tracers_pressure\L834\T35
# file 8series_tracers_pressure\L834\T37
# file 8series_tracers_pressure\L834\T39
# file 8series_tracers_pressure\L834\T40
# file 8series_tracers_pressure\L834\T5
# file 8series_tracers_pressure\L834\T7
# file 8series_tracers_pressure\L834\T9
# folder 8series_tracers_pressure\L838
# file 8series_tracers_pressure\L838\T11
# file 8series_tracers_pressure\L838\T13
# file 8series_tracers_pressure\L838\T15
# file 8series_tracers_pressure\L838\T17
# file 8series_tracers_pressure\L838\T19
# file 8series_tracers_pressure\L838\T2
# file 8series_tracers_pressure\L838\T21
# file 8series_tracers_pressure\L838\T23
# file 8series_tracers_pressure\L838\T25
# file 8series_tracers_pressure\L838\T27
# file 8series_tracers_pressure\L838\T29
# file 8series_tracers_pressure\L838\T3
# file 8series_tracers_pressure\L838\T31
# file 8series_tracers_pressure\L838\T33
# file 8series_tracers_pressure\L838\T35
# file 8series_tracers_pressure\L838\T37
# file 8series_tracers_pressure\L838\T39
# file 8series_tracers_pressure\L838\T40
# file 8series_tracers_pressure\L838\T5
# file 8series_tracers_pressure\L838\T7
# file 8series_tracers_pressure\L838\T9
# folder 8series_tracers_pressure\L842
# file 8series_tracers_pressure\L842\T11
# file 8series_tracers_pressure\L842\T13
# file 8series_tracers_pressure\L842\T15
# file 8series_tracers_pressure\L842\T17
# file 8series_tracers_pressure\L842\T19
# file 8series_tracers_pressure\L842\T2
# file 8series_tracers_pressure\L842\T21
# file 8series_tracers_pressure\L842\T23
# file 8series_tracers_pressure\L842\T25
# file 8series_tracers_pressure\L842\T27
# file 8series_tracers_pressure\L842\T29
# file 8series_tracers_pressure\L842\T3
# file 8series_tracers_pressure\L842\T31
# file 8series_tracers_pressure\L842\T33
# file 8series_tracers_pressure\L842\T35
# file 8series_tracers_pressure\L842\T37
# file 8series_tracers_pressure\L842\T39
# file 8series_tracers_pressure\L842\T40
# file 8series_tracers_pressure\L842\T5
# file 8series_tracers_pressure\L842\T7
# file 8series_tracers_pressure\L842\T9
# folder 8series_tracers_pressure\L846
# file 8series_tracers_pressure\L846\T11
# file 8series_tracers_pressure\L846\T13
# file 8series_tracers_pressure\L846\T15
# file 8series_tracers_pressure\L846\T17
# file 8series_tracers_pressure\L846\T19
# file 8series_tracers_pressure\L846\T2
# file 8series_tracers_pressure\L846\T21
# file 8series_tracers_pressure\L846\T23
# file 8series_tracers_pressure\L846\T25
# file 8series_tracers_pressure\L846\T27
# file 8series_tracers_pressure\L846\T29
# file 8series_tracers_pressure\L846\T3
# file 8series_tracers_pressure\L846\T31
# file 8series_tracers_pressure\L846\T33
# file 8series_tracers_pressure\L846\T35
# file 8series_tracers_pressure\L846\T37
# file 8series_tracers_pressure\L846\T39
# file 8series_tracers_pressure\L846\T40
# file 8series_tracers_pressure\L846\T5
# file 8series_tracers_pressure\L846\T7
# file 8series_tracers_pressure\L846\T9
# folder 8series_tracers_pressure\L850
# file 8series_tracers_pressure\L850\T11
# file 8series_tracers_pressure\L850\T13
# file 8series_tracers_pressure\L850\T15
# file 8series_tracers_pressure\L850\T17
# file 8series_tracers_pressure\L850\T19
# file 8series_tracers_pressure\L850\T2
# file 8series_tracers_pressure\L850\T21
# file 8series_tracers_pressure\L850\T23
# file 8series_tracers_pressure\L850\T25
# file 8series_tracers_pressure\L850\T27
# file 8series_tracers_pressure\L850\T29
# file 8series_tracers_pressure\L850\T3
# file 8series_tracers_pressure\L850\T31
# file 8series_tracers_pressure\L850\T33
# file 8series_tracers_pressure\L850\T35
# file 8series_tracers_pressure\L850\T37
# file 8series_tracers_pressure\L850\T39
# file 8series_tracers_pressure\L850\T40
# file 8series_tracers_pressure\L850\T5
# file 8series_tracers_pressure\L850\T7
# file 8series_tracers_pressure\L850\T9
#     Explosive type  Explosive mass  Standoff_distance  Peak_Pressure
# 0    Composition B             0.5                5.5        118.499
# 1    Composition B             0.5                6.5        114.539
# 2    Composition B             0.5                7.5        111.882
# 3    Composition B             0.5                8.5        109.969
# 4    Composition B             0.5                9.5        108.552
# ..             ...             ...                ...            ...
# 310  Composition B            25.0               19.5        119.682
# 311  Composition B            25.0               20.0        118.965
# 312  Composition B            25.0                2.5       1550.450
# 313  Composition B            25.0                3.5        724.539
# 314  Composition B            25.0                4.5        425.238
#
# [315 rows x 4 columns]

# %% [markdown]
# # Create peak pressure file - Attempt 2 (with peak index)

# %% [markdown]
# ## Access input folders 2

# %%
#Access input folder
input_dir3 = Path ("Pressure_curves_excel_with_MinMaxTime")
print ("3",input_dir3)

#Access folders inside input folder
input_dir4 =  [folder for folder in input_dir3.iterdir() if folder.is_dir()]
print ("4",input_dir4)

# %% [markdown]
# ## Create peak pressure dataframe

# %%
df1 = pd.DataFrame(columns = ['Charge_mass', 'Standoff_distance', 'Peak pressure', 'Peak time', 'Peak index'])
# Access each folder inside input folder
for folder in input_dir4:
    print ("folder", folder)
    charge_mass = int(folder.stem[4:])/2
    
    # Make a list of data file names
    files = list(folder.rglob("*"))
        
    # Access each file 
    for file in files:
        wrkbk = openpyxl.load_workbook(file)
        sh = wrkbk.active
        stand_dis = math.ceil(int(file.stem[1:])/2)
        peak_time = sh.cell(row = 2, column = 4)
        print ('file', file, 'peak_time', peak_time.value)
        
        # iterate through excel and display data
        for i in range(2, sh.max_row+1):
            cell_time = sh.cell (row = i, column = 1)
            #print (cell_time.value)
            if round(cell_time.value, 10) >= peak_time.value:
                print ("cell_time", cell_time.value)
                peak_index = i
                peak_pressure = sh.cell (row = i, column = 2)
                print ("peak_index", i, 'peak_pressure', peak_pressure.value)
                
                # append rows to an empty DataFrame
                new_row = {'Charge_mass' : [charge_mass],
                           'Standoff_distance' : [stand_dis],
                           'Peak pressure' : [peak_pressure.value],
                           'Peak time' : [peak_time.value],
                           'Peak index' : [i]}
                new_row_data = pd.DataFrame(new_row)
                df1 = pd.concat([df1, new_row_data], ignore_index = True)
                break

# %%
print (df1)
# Out:
#    0        1         2   3      4         5
# 0  *  Maxval=  425238.0  at  time=  0.003524

# %% [markdown]
# ## Create peak pressure excel file

# %%
with pd.ExcelWriter('Peak_Incident_Pressure_CompB.xlsx', engine = "openpyxl", mode='a', if_sheet_exists='replace') as writer:  
    df.to_excel(writer, sheet_name = "Sheet1", index = False, header = True)

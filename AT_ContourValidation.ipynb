# %% [markdown]
# ## Import libraries

# %%
from pathlib import Path
import pandas as pd
import openpyxl
import math

# %% [markdown]
# ## Access input and output directories

# %%
#Access input folder
input_dir1 = Path('G:\Chamodi\LSDYNA_1D\Contour_validation\Peak_incident_pressure\Excel')
print ("1",input_dir1)

#Access folders inside input folder
input_dir2 =  [folder for folder in input_dir1.iterdir() if folder.is_dir()]
print ("2",input_dir2)
# Out:
# 1 G:\Chamodi\LSDYNA_1D\Contour_validation\Peak_incident_pressure\Excel
# 2 [WindowsPath('G:/Chamodi/LSDYNA_1D/Contour_validation/Peak_incident_pressure/Excel/Tracers')]

# %% [markdown]
# ## Filtering arrival time

# %%
# Access each folder inside input folder
df = pd.DataFrame(columns = ['Standoff distance', 'Time of arrival'])
 
for folder in input_dir2:
    
    # Make a list of data file names
    files = list(folder.rglob("*.xlsx"))
    
    for file in files:
        stand_dis=5.65
        wrkbk = openpyxl.load_workbook(file)
        sh = wrkbk.active
        a=0
        stand_dis = stand_dis+(0.05*int(file.stem))
        
        # iterate through excel and display data
        for i in range(2, sh.max_row+1):
            cell_pressure = sh.cell (row = i, column = 2)
            if cell_pressure.value > 100000:
                print (file.stem)
                print ("pressure", cell_pressure.value)
                cell_time = sh.cell (row = i, column = 1)
                print ("time of arrival", cell_time.value)
                # append rows to an empty DataFrame
                new_row = {'Standoff distance' : [stand_dis],
                           'Time of arrival' : [cell_time.value]}
                new_row_data = pd.DataFrame(new_row)
                df = pd.concat([df, new_row_data], ignore_index = True)
                a=a+1
            if a == 1:
                break
# Out:
# 1
# pressure 100007
# time of arrival 0.0066698999144
# 10
# pressure 100007
# time of arrival 0.0076500000432
# 100
# pressure 100051
# time of arrival 0.018799999729
# 101
# pressure 100011
# time of arrival 0.018929999322
# 102
# pressure 100003
# time of arrival 0.019060000777
# 103
# pressure 100037
# time of arrival 0.019200000912
# 104
# pressure 100009
# time of arrival 0.019330000505
# 105
# pressure 100002
# time of arrival 0.019460000098
# 106
# pressure 100083
# time of arrival 0.019600000232
# 107
# pressure 100015
# time of arrival 0.019729999825
# 108
# pressure 100009
# time of arrival 0.019859999418
# 109
# pressure 100002
# time of arrival 0.019990000874
# 11
# pressure 100002
# time of arrival 0.0077598001808
# 110
# pressure 100051
# time of arrival 0.020129999146
# 111
# pressure 100008
# time of arrival 0.020260000601
# 112
# pressure 100001
# time of arrival 0.020390000194
# 113
# pressure 100001
# time of arrival 0.020390000194
# 114
# pressure 100004
# time of arrival 0.020659999922
# 115
# pressure 100079
# time of arrival 0.020800000057
# 116
# pressure 100009
# time of arrival 0.02092999965
# 117
# pressure 100001
# time of arrival 0.021059999242
# 118
# pressure 100005
# time of arrival 0.021199999377
# 119
# pressure 100005
# time of arrival 0.021199999377
# 12
# pressure 109379
# time of arrival 0.0078798998147
# 120
# pressure 100034
# time of arrival 0.021469999105
# 121
# pressure 100003
# time of arrival 0.02160000056
# 122
# pressure 100045
# time of arrival 0.021740000695
# 123
# pressure 100001
# time of arrival 0.021870000288
# 124
# pressure 100012
# time of arrival 0.022010000423
# 125
# time of arrival 0.013120000251
# 57
# pressure 100001
# time of arrival 0.013240000233
# 58
# pressure 100004
# time of arrival 0.013369999826
# 59
# pressure 100546
# time of arrival 0.01350000035
# 6
# pressure 100001
# time of arrival 0.0072098998353
# 60
# pressure 100008
# time of arrival 0.013620000333
# 61
# pressure 100122
# time of arrival 0.013749999925
# 62
# pressure 100002
# time of arrival 0.013869999908
# 63
# pressure 100003
# time of arrival 0.014000000432
# 64
# pressure 100036
# time of arrival 0.014130000025
# 65
# pressure 100313
# time of arrival 0.014259999618
# 66
# pressure 100002
# time of arrival 0.0143799996
# 67
# pressure 100015
# time of arrival 0.014510000125
# 68
# pressure 100001
# time of arrival 0.014630000107
# 69
# pressure 100003
# time of arrival 0.0147599997
# 7
# pressure 100002
# time of arrival 0.0073199002072
# 70
# pressure 100013
# time of arrival 0.014890000224
# 71
# pressure 100052
# time of arrival 0.015019999817
# 72
# pressure 100158
# time of arrival 0.015150000341
# 73
# pressure 100094
# time of arrival 0.015279999934
# 74
# pressure 100002
# time of arrival 0.015399999917
# 75
# pressure 100005
# time of arrival 0.015530000441
# 76
# pressure 100009
# time of arrival 0.015659999102
# 77
# pressure 100019
# time of arrival 0.015790000558
# 78
# pressure 100006
# time of arrival 0.015920000151
# 79
# pressure 100045
# time of arrival 0.016049999744
# 8
# pressure 100018
# time of arrival 0.0074297999963
# 80
# pressure 100071
# time of arrival 0.016179999337
# 81
# pressure 100082
# time of arrival 0.016310000792
# 82
# pressure 100100
# time of arrival 0.016440000385
# 83
# pressure 100019
# time of arrival 0.016569999978
# 84
# pressure 100017
# time of arrival 0.016699999571
# 85
# pressure 100015
# time of arrival 0.016829999164
# 86
# pressure 100012
# time of arrival 0.016960000619
# 87
# pressure 100009
# time of arrival 0.017090000212
# 88
# pressure 100029
# time of arrival 0.017219999805
# 89
# pressure 100016
# time of arrival 0.017349999398
# 9
# pressure 100014
# time of arrival 0.0075399000198
# 90
# pressure 100009
# time of arrival 0.017480000854
# 91
# pressure 100005
# time of arrival 0.017610000446
# 92
# pressure 100002
# time of arrival 0.017740000039
# 93
# pressure 100071
# time of arrival 0.017880000174
# 94
# pressure 100156
# time of arrival 0.018009999767
# 95
# pressure 100059
# time of arrival 0.01813999936
# 96
# pressure 100022
# time of arrival 0.018270000815
# 97
# pressure 100006
# time of arrival 0.018400000408
# 98
# pressure 100133
# time of arrival 0.018540000543
# 99
# pressure 100001
# time of arrival 0.018659999594

# %%
print (df)
# Out:
#      Standoff distance  Time of arrival
# 0                 5.70          0.00667
# 1                 6.15          0.00765
# 2                10.65          0.01880
# 3                10.70          0.01893
# 4                10.75          0.01906
# ..                 ...              ...
# 131              10.40          0.01814
# 132              10.45          0.01827
# 133              10.50          0.01840
# 134              10.55          0.01854
# 135              10.60          0.01866
#
# [136 rows x 2 columns]

# %% [markdown]
# ## Create Arrival_time excel file

# %%
with pd.ExcelWriter('AT_ContourVal.xlsx', engine = "openpyxl", mode='a', if_sheet_exists='replace') as writer:  
    df.to_excel(writer, sheet_name = "Sheet1", index = False, header = True)
